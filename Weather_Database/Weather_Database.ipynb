# %%
# Import the dependencies.
import pandas as pd
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current_description=city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                         "Current Description":city_current_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | saint-philippe
# Processing Record 2 of Set 1 | jamestown
# Processing Record 3 of Set 1 | busselton
# Processing Record 4 of Set 1 | mayo
# Processing Record 5 of Set 1 | ribeira grande
# Processing Record 6 of Set 1 | fairbanks
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 9 of Set 1 | kijang
# Processing Record 10 of Set 1 | hilo
# Processing Record 11 of Set 1 | bambous virieux
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | kapaa
# Processing Record 14 of Set 1 | mareeba
# Processing Record 15 of Set 1 | ancud
# Processing Record 16 of Set 1 | yellowknife
# Processing Record 17 of Set 1 | ostrovnoy
# Processing Record 18 of Set 1 | port macquarie
# Processing Record 19 of Set 1 | verkhoyansk
# Processing Record 20 of Set 1 | sedelnikovo
# City not found. Skipping...
# Processing Record 21 of Set 1 | severo-kurilsk
# Processing Record 22 of Set 1 | bathsheba
# Processing Record 23 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 24 of Set 1 | mataura
# Processing Record 25 of Set 1 | mulege
# Processing Record 26 of Set 1 | nuuk
# Processing Record 27 of Set 1 | port alfred
# Processing Record 28 of Set 1 | domoni
# Processing Record 29 of Set 1 | hithadhoo
# Processing Record 30 of Set 1 | khani
# Processing Record 31 of Set 1 | kaitangata
# Processing Record 32 of Set 1 | salalah
# Processing Record 33 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 34 of Set 1 | leh
# Processing Record 35 of Set 1 | dhidhdhoo
# Processing Record 36 of Set 1 | leua
# Processing Record 37 of Set 1 | new norfolk
# Processing Record 38 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 39 of Set 1 | qaanaaq
# Processing Record 40 of Set 1 | warwick
# Processing Record 41 of Set 1 | cidreira
# Processing Record 42 of Set 1 | hays
# Processing Record 43 of Set 1 | utiroa
# City not found. Skipping...
# Processing Record 44 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 45 of Set 1 | rottingdean
# Processing Record 46 of Set 1 | punta arenas
# Processing Record 47 of Set 1 | dhankuta
# Processing Record 48 of Set 1 | dikson
# Processing Record 49 of Set 1 | dumas
# Processing Record 50 of Set 1 | puerto ayora
# Processing Record 1 of Set 2 | fort saint john
# City not found. Skipping...
# Processing Record 2 of Set 2 | port-de-bouc
# Processing Record 3 of Set 2 | bengkulu
# Processing Record 4 of Set 2 | parker
# Processing Record 5 of Set 2 | isangel
# Processing Record 6 of Set 2 | zhongshu
# Processing Record 7 of Set 2 | bluff
# Processing Record 8 of Set 2 | carnarvon
# Processing Record 9 of Set 2 | pizarro
# Processing Record 10 of Set 2 | victoria
# Processing Record 11 of Set 2 | bilibino
# Processing Record 12 of Set 2 | albany
# Processing Record 13 of Set 2 | buon me thuot
# City not found. Skipping...
# Processing Record 14 of Set 2 | buchanan
# Processing Record 15 of Set 2 | kodiak
# Processing Record 16 of Set 2 | taganak
# Processing Record 17 of Set 2 | mandalgovi
# Processing Record 18 of Set 2 | port hedland
# Processing Record 19 of Set 2 | walvis bay
# Processing Record 20 of Set 2 | ngukurr
# City not found. Skipping...
# Processing Record 21 of Set 2 | nikolskoye
# Processing Record 22 of Set 2 | klaksvik
# Processing Record 23 of Set 2 | east london
# Processing Record 24 of Set 2 | bethel
# Processing Record 25 of Set 2 | waipawa
# Processing Record 26 of Set 2 | ponta do sol
# Processing Record 27 of Set 2 | kyra
# Processing Record 28 of Set 2 | cherskiy
# Processing Record 29 of Set 2 | arraial do cabo
# Processing Record 30 of Set 2 | manta
# Processing Record 31 of Set 2 | namwala
# Processing Record 32 of Set 2 | avarua
# Processing Record 33 of Set 2 | verkhnevilyuysk
# Processing Record 34 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 35 of Set 2 | paragominas
# Processing Record 36 of Set 2 | fort nelson
# Processing Record 37 of Set 2 | korla
# Processing Record 38 of Set 2 | lebu
# Processing Record 39 of Set 2 | moorhead
# Processing Record 40 of Set 2 | kerema
# Processing Record 41 of Set 2 | koumac
# Processing Record 42 of Set 2 | upernavik
# Processing Record 43 of Set 2 | arona
# Processing Record 44 of Set 2 | kavieng
# Processing Record 45 of Set 2 | cape town
# Processing Record 46 of Set 2 | butaritari
# Processing Record 47 of Set 2 | hobart
# Processing Record 48 of Set 2 | jurm
# Processing Record 49 of Set 2 | belaya gora
# Processing Record 50 of Set 2 | yar-sale
# Processing Record 1 of Set 3 | mount gambier
# Processing Record 2 of Set 3 | tuktoyaktuk
# Processing Record 3 of Set 3 | abu samrah
# Processing Record 4 of Set 3 | inhambane
# Processing Record 5 of Set 3 | geraldton
# Processing Record 6 of Set 3 | hermanus
# Processing Record 7 of Set 3 | nguiu
# City not found. Skipping...
# Processing Record 8 of Set 3 | batagay
# Processing Record 9 of Set 3 | ormara
# Processing Record 10 of Set 3 | barrow
# Processing Record 11 of Set 3 | castro
# Processing Record 12 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 3 | mar del plata
# Processing Record 14 of Set 3 | tiksi
# Processing Record 15 of Set 3 | sangar
# Processing Record 16 of Set 3 | ballina
# Processing Record 17 of Set 3 | payo
# Processing Record 18 of Set 3 | saint george
# Processing Record 19 of Set 3 | atuona
# Processing Record 20 of Set 3 | faya
# Processing Record 21 of Set 3 | belturbet
# Processing Record 22 of Set 3 | barda
# Processing Record 23 of Set 3 | outjo
# Processing Record 24 of Set 3 | strelca
# City not found. Skipping...
# Processing Record 25 of Set 3 | santander jimenez
# Processing Record 26 of Set 3 | longyearbyen
# Processing Record 27 of Set 3 | khatanga
# Processing Record 28 of Set 3 | touros
# Processing Record 29 of Set 3 | aquiraz
# Processing Record 30 of Set 3 | codrington
# Processing Record 31 of Set 3 | torit
# Processing Record 32 of Set 3 | torbay
# Processing Record 33 of Set 3 | havelock
# Processing Record 34 of Set 3 | buwenge
# Processing Record 35 of Set 3 | port elizabeth
# Processing Record 36 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 37 of Set 3 | coahuayana
# Processing Record 38 of Set 3 | cururupu
# Processing Record 39 of Set 3 | vila franca do campo
# Processing Record 40 of Set 3 | vestmannaeyjar
# Processing Record 41 of Set 3 | bolgatanga
# Processing Record 42 of Set 3 | mahebourg
# Processing Record 43 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 44 of Set 3 | qaqortoq
# Processing Record 45 of Set 3 | fountain hills
# Processing Record 46 of Set 3 | norman wells
# Processing Record 47 of Set 3 | zhuhai
# Processing Record 48 of Set 3 | xihe
# Processing Record 49 of Set 3 | townsville
# Processing Record 50 of Set 3 | chokurdakh
# Processing Record 1 of Set 4 | bell ville
# Processing Record 2 of Set 4 | abha
# Processing Record 3 of Set 4 | vila
# Processing Record 4 of Set 4 | vaini
# Processing Record 5 of Set 4 | whitehorse
# Processing Record 6 of Set 4 | guerrero negro
# Processing Record 7 of Set 4 | bredasdorp
# Processing Record 8 of Set 4 | souillac
# Processing Record 9 of Set 4 | nueva germania
# Processing Record 10 of Set 4 | dunmore east
# Processing Record 11 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 12 of Set 4 | san patricio
# Processing Record 13 of Set 4 | constitucion
# Processing Record 14 of Set 4 | kruisfontein
# Processing Record 15 of Set 4 | valladolid
# Processing Record 16 of Set 4 | clarksdale
# Processing Record 17 of Set 4 | khorixas
# Processing Record 18 of Set 4 | robertsport
# Processing Record 19 of Set 4 | turukhansk
# Processing Record 20 of Set 4 | puerto madero
# Processing Record 21 of Set 4 | businga
# Processing Record 22 of Set 4 | macia
# Processing Record 23 of Set 4 | tasiilaq
# Processing Record 24 of Set 4 | ust-kan
# Processing Record 25 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 26 of Set 4 | dakar
# Processing Record 27 of Set 4 | juneau
# Processing Record 28 of Set 4 | merauke
# Processing Record 29 of Set 4 | jumla
# Processing Record 30 of Set 4 | skjervoy
# Processing Record 31 of Set 4 | faanui
# Processing Record 32 of Set 4 | treinta y tres
# Processing Record 33 of Set 4 | plattsburgh
# Processing Record 34 of Set 4 | kartaly
# Processing Record 35 of Set 4 | ibra
# Processing Record 36 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 37 of Set 4 | turayf
# Processing Record 38 of Set 4 | north bend
# Processing Record 39 of Set 4 | manica
# Processing Record 40 of Set 4 | simpang
# Processing Record 41 of Set 4 | dingle
# Processing Record 42 of Set 4 | yerbogachen
# Processing Record 43 of Set 4 | talnakh
# Processing Record 44 of Set 4 | garchitorena
# Processing Record 45 of Set 4 | adjumani
# Processing Record 46 of Set 4 | novyy urgal
# Processing Record 47 of Set 4 | benguela
# Processing Record 48 of Set 4 | nalut
# Processing Record 49 of Set 4 | angoram
# Processing Record 50 of Set 4 | along
# Processing Record 1 of Set 5 | machilipatnam
# Processing Record 2 of Set 5 | katsuura
# Processing Record 3 of Set 5 | omsukchan
# Processing Record 4 of Set 5 | comodoro rivadavia
# Processing Record 5 of Set 5 | pinsk
# Processing Record 6 of Set 5 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 7 of Set 5 | quibor
# Processing Record 8 of Set 5 | ailigandi
# Processing Record 9 of Set 5 | umm lajj
# Processing Record 10 of Set 5 | karamay
# City not found. Skipping...
# Processing Record 11 of Set 5 | nome
# Processing Record 12 of Set 5 | andilamena
# Processing Record 13 of Set 5 | ituni
# City not found. Skipping...
# Processing Record 14 of Set 5 | omboue
# Processing Record 15 of Set 5 | kinkala
# Processing Record 16 of Set 5 | sitka
# Processing Record 17 of Set 5 | vostok
# Processing Record 18 of Set 5 | harrison
# Processing Record 19 of Set 5 | cumaribo
# City not found. Skipping...
# Processing Record 20 of Set 5 | harper
# Processing Record 21 of Set 5 | coylton
# Processing Record 22 of Set 5 | hokitika
# Processing Record 23 of Set 5 | barcelos
# Processing Record 24 of Set 5 | haines junction
# Processing Record 25 of Set 5 | urumqi
# Processing Record 26 of Set 5 | bandarbeyla
# Processing Record 27 of Set 5 | taoudenni
# Processing Record 28 of Set 5 | chuy
# Processing Record 29 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 30 of Set 5 | beoumi
# Processing Record 31 of Set 5 | deputatskiy
# Processing Record 32 of Set 5 | komsomolskiy
# Processing Record 33 of Set 5 | acajutla
# Processing Record 34 of Set 5 | iqaluit
# Processing Record 35 of Set 5 | shimoda
# Processing Record 36 of Set 5 | victor harbor
# Processing Record 37 of Set 5 | padang
# Processing Record 38 of Set 5 | lazurne
# Processing Record 39 of Set 5 | bonavista
# Processing Record 40 of Set 5 | aksu
# Processing Record 41 of Set 5 | itarema
# Processing Record 42 of Set 5 | okhotsk
# Processing Record 43 of Set 5 | oussouye
# Processing Record 44 of Set 5 | meadow lake
# Processing Record 45 of Set 5 | kavaratti
# Processing Record 46 of Set 5 | garmsar
# Processing Record 47 of Set 5 | campina verde
# Processing Record 48 of Set 5 | george town
# Processing Record 49 of Set 5 | provideniya
# Processing Record 50 of Set 5 | nedjo
# Processing Record 1 of Set 6 | hamilton
# Processing Record 2 of Set 6 | zholymbet
# Processing Record 3 of Set 6 | daxian
# City not found. Skipping...
# Processing Record 4 of Set 6 | pokhara
# Processing Record 5 of Set 6 | akyab
# Processing Record 6 of Set 6 | yuncheng
# Processing Record 7 of Set 6 | husavik
# Processing Record 8 of Set 6 | natal
# Processing Record 9 of Set 6 | kajaani
# Processing Record 10 of Set 6 | beringovskiy
# Processing Record 11 of Set 6 | airai
# Processing Record 12 of Set 6 | tecoanapa
# Processing Record 13 of Set 6 | bako
# Processing Record 14 of Set 6 | yambio
# Processing Record 15 of Set 6 | stekolnyy
# City not found. Skipping...
# Processing Record 16 of Set 6 | heihe
# Processing Record 17 of Set 6 | paka
# Processing Record 18 of Set 6 | ust-maya
# Processing Record 19 of Set 6 | hasaki
# Processing Record 20 of Set 6 | rio gallegos
# Processing Record 21 of Set 6 | samarkand
# Processing Record 22 of Set 6 | flinders
# Processing Record 23 of Set 6 | georgetown
# Processing Record 24 of Set 6 | fort-shevchenko
# Processing Record 25 of Set 6 | wellington
# Processing Record 26 of Set 6 | hualmay
# Processing Record 27 of Set 6 | trat
# Processing Record 28 of Set 6 | luganville
# Processing Record 29 of Set 6 | praia da vitoria
# Processing Record 30 of Set 6 | lisakovsk
# Processing Record 31 of Set 6 | las vegas
# Processing Record 32 of Set 6 | quatre cocos
# Processing Record 33 of Set 6 | pandan
# Processing Record 34 of Set 6 | kalabo
# Processing Record 35 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 36 of Set 6 | santa cruz del sur
# Processing Record 37 of Set 6 | port hardy
# Processing Record 38 of Set 6 | ust-tsilma
# Processing Record 39 of Set 6 | hailun
# Processing Record 40 of Set 6 | sabang
# Processing Record 41 of Set 6 | pervomaysk
# Processing Record 42 of Set 6 | lorengau
# Processing Record 43 of Set 6 | samarai
# Processing Record 44 of Set 6 | cabo san lucas
# Processing Record 45 of Set 6 | pangnirtung
# Processing Record 46 of Set 6 | pevek
# Processing Record 47 of Set 6 | camacha
# Processing Record 48 of Set 6 | narsaq
# Processing Record 49 of Set 6 | abilene
# Processing Record 50 of Set 6 | ilulissat
# Processing Record 1 of Set 7 | jiaojiang
# Processing Record 2 of Set 7 | fortuna
# Processing Record 3 of Set 7 | palana
# Processing Record 4 of Set 7 | olinda
# Processing Record 5 of Set 7 | anadyr
# Processing Record 6 of Set 7 | saint-augustin
# Processing Record 7 of Set 7 | santana do livramento
# Processing Record 8 of Set 7 | grand gaube
# Processing Record 9 of Set 7 | tenkodogo
# Processing Record 10 of Set 7 | sao filipe
# Processing Record 11 of Set 7 | los llanos de aridane
# Processing Record 12 of Set 7 | gizo
# Processing Record 13 of Set 7 | broken hill
# Processing Record 14 of Set 7 | yumen
# Processing Record 15 of Set 7 | salamanca
# Processing Record 16 of Set 7 | ahipara
# Processing Record 17 of Set 7 | pisco
# Processing Record 18 of Set 7 | poum
# Processing Record 19 of Set 7 | saint-pierre
# Processing Record 20 of Set 7 | tateyama
# Processing Record 21 of Set 7 | hauterive
# Processing Record 22 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 23 of Set 7 | tarakan
# Processing Record 24 of Set 7 | viedma
# Processing Record 25 of Set 7 | sug-aksy
# City not found. Skipping...
# Processing Record 26 of Set 7 | laguna
# Processing Record 27 of Set 7 | kalga
# Processing Record 28 of Set 7 | port hawkesbury
# Processing Record 29 of Set 7 | lusambo
# Processing Record 30 of Set 7 | alotau
# City not found. Skipping...
# Processing Record 31 of Set 7 | chinsali
# Processing Record 32 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 33 of Set 7 | alanya
# Processing Record 34 of Set 7 | kununurra
# Processing Record 35 of Set 7 | sovetskaya gavan
# Processing Record 36 of Set 7 | svetlyy
# Processing Record 37 of Set 7 | liancheng
# Processing Record 38 of Set 7 | thompson
# Processing Record 39 of Set 7 | usinsk
# Processing Record 40 of Set 7 | biggar
# Processing Record 41 of Set 7 | redlands
# Processing Record 42 of Set 7 | saryshagan
# City not found. Skipping...
# Processing Record 43 of Set 7 | carutapera
# Processing Record 44 of Set 7 | qiongshan
# Processing Record 45 of Set 7 | gold coast
# Processing Record 46 of Set 7 | richards bay
# Processing Record 47 of Set 7 | santa marta
# Processing Record 48 of Set 7 | lompoc
# Processing Record 49 of Set 7 | bulgan
# Processing Record 50 of Set 7 | maceio
# Processing Record 1 of Set 8 | port blair
# Processing Record 2 of Set 8 | debno
# Processing Record 3 of Set 8 | luderitz
# Processing Record 4 of Set 8 | san andres
# Processing Record 5 of Set 8 | lincoln
# Processing Record 6 of Set 8 | noshiro
# Processing Record 7 of Set 8 | miyako
# Processing Record 8 of Set 8 | bubaque
# Processing Record 9 of Set 8 | dalnegorsk
# Processing Record 10 of Set 8 | tual
# Processing Record 11 of Set 8 | sars
# Processing Record 12 of Set 8 | manggar
# Processing Record 13 of Set 8 | balkanabat
# Processing Record 14 of Set 8 | aketi
# Processing Record 15 of Set 8 | ewa beach
# Processing Record 16 of Set 8 | skorodnoye
# Processing Record 17 of Set 8 | yuzhnouralsk
# Processing Record 18 of Set 8 | rawson
# Processing Record 19 of Set 8 | zaplavnoye
# Processing Record 20 of Set 8 | kulhudhuffushi
# Processing Record 21 of Set 8 | bilma
# Processing Record 22 of Set 8 | wakkanai
# Processing Record 23 of Set 8 | port lincoln
# Processing Record 24 of Set 8 | half moon bay
# Processing Record 25 of Set 8 | xai-xai
# Processing Record 26 of Set 8 | sobolevo
# Processing Record 27 of Set 8 | matane
# Processing Record 28 of Set 8 | beyneu
# Processing Record 29 of Set 8 | camopi
# Processing Record 30 of Set 8 | aasiaat
# Processing Record 31 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 32 of Set 8 | zofingen
# Processing Record 33 of Set 8 | pennagaram
# Processing Record 34 of Set 8 | severo-yeniseyskiy
# Processing Record 35 of Set 8 | dudinka
# Processing Record 36 of Set 8 | beloha
# Processing Record 37 of Set 8 | grindavik
# Processing Record 38 of Set 8 | nanortalik
# Processing Record 39 of Set 8 | abeche
# Processing Record 40 of Set 8 | clyde river
# Processing Record 41 of Set 8 | lavrentiya
# Processing Record 42 of Set 8 | chapais
# Processing Record 43 of Set 8 | ngunguru
# Processing Record 44 of Set 8 | ishigaki
# Processing Record 45 of Set 8 | staryy nadym
# Processing Record 46 of Set 8 | saskylakh
# Processing Record 47 of Set 8 | palmeiras de goias
# Processing Record 48 of Set 8 | port augusta
# Processing Record 49 of Set 8 | lesogorsk
# Processing Record 50 of Set 8 | balkhash
# Processing Record 1 of Set 9 | santo amaro da imperatriz
# Processing Record 2 of Set 9 | vredendal
# Processing Record 3 of Set 9 | billings
# Processing Record 4 of Set 9 | santo andre
# Processing Record 5 of Set 9 | cap malheureux
# Processing Record 6 of Set 9 | fare
# Processing Record 7 of Set 9 | ambulu
# Processing Record 8 of Set 9 | shibarghan
# City not found. Skipping...
# Processing Record 9 of Set 9 | road town
# Processing Record 10 of Set 9 | dunedin
# Processing Record 11 of Set 9 | leningradskiy
# Processing Record 12 of Set 9 | mudu
# Processing Record 13 of Set 9 | salym
# Processing Record 14 of Set 9 | maragogi
# Processing Record 15 of Set 9 | tula
# Processing Record 16 of Set 9 | tambopata
# Processing Record 17 of Set 9 | huntsville
# Processing Record 18 of Set 9 | cardinal
# Processing Record 19 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 20 of Set 9 | zaltan
# Processing Record 21 of Set 9 | chilca
# Processing Record 22 of Set 9 | tarauaca
# Processing Record 23 of Set 9 | akcaabat
# Processing Record 24 of Set 9 | banjar
# Processing Record 25 of Set 9 | kaeo
# Processing Record 26 of Set 9 | les cayes
# Processing Record 27 of Set 9 | rosetta
# Processing Record 28 of Set 9 | ust-nera
# Processing Record 29 of Set 9 | arroyo
# Processing Record 30 of Set 9 | qasigiannguit
# Processing Record 31 of Set 9 | ouallam
# Processing Record 32 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 33 of Set 9 | bosaso
# Processing Record 34 of Set 9 | port-gentil
# Processing Record 35 of Set 9 | mamakan
# Processing Record 36 of Set 9 | ambilobe
# Processing Record 37 of Set 9 | chauk
# Processing Record 38 of Set 9 | puerto madryn
# Processing Record 39 of Set 9 | san carlos de bariloche
# Processing Record 40 of Set 9 | peleduy
# Processing Record 41 of Set 9 | neyshabur
# Processing Record 42 of Set 9 | antofagasta
# Processing Record 43 of Set 9 | bowen
# Processing Record 44 of Set 9 | bageshwar
# Processing Record 45 of Set 9 | rayong
# Processing Record 46 of Set 9 | bada
# Processing Record 47 of Set 9 | kirakira
# Processing Record 48 of Set 9 | kavali
# Processing Record 49 of Set 9 | shache
# Processing Record 50 of Set 9 | uzventis
# Processing Record 1 of Set 10 | vallenar
# Processing Record 2 of Set 10 | moyo
# Processing Record 3 of Set 10 | camana
# Processing Record 4 of Set 10 | bay city
# Processing Record 5 of Set 10 | ciocile
# Processing Record 6 of Set 10 | ischia
# Processing Record 7 of Set 10 | college
# Processing Record 8 of Set 10 | mamlyutka
# Processing Record 9 of Set 10 | nakhon si thammarat
# Processing Record 10 of Set 10 | karlstad
# Processing Record 11 of Set 10 | meulaboh
# Processing Record 12 of Set 10 | karratha
# Processing Record 13 of Set 10 | palmas
# Processing Record 14 of Set 10 | avera
# Processing Record 15 of Set 10 | coihaique
# Processing Record 16 of Set 10 | reconquista
# Processing Record 17 of Set 10 | vestmanna
# Processing Record 18 of Set 10 | whitefish
# Processing Record 19 of Set 10 | takoradi
# Processing Record 20 of Set 10 | ambon
# Processing Record 21 of Set 10 | sao paulo de olivenca
# Processing Record 22 of Set 10 | timoteo
# Processing Record 23 of Set 10 | saldanha
# Processing Record 24 of Set 10 | genhe
# Processing Record 25 of Set 10 | neiafu
# Processing Record 26 of Set 10 | vilela
# Processing Record 27 of Set 10 | koboko
# Processing Record 28 of Set 10 | altay
# Processing Record 29 of Set 10 | ruatoria
# City not found. Skipping...
# Processing Record 30 of Set 10 | latung
# Processing Record 31 of Set 10 | vao
# Processing Record 32 of Set 10 | bontang
# Processing Record 33 of Set 10 | gore
# Processing Record 34 of Set 10 | katangli
# Processing Record 35 of Set 10 | houma
# Processing Record 36 of Set 10 | seredka
# Processing Record 37 of Set 10 | varhaug
# Processing Record 38 of Set 10 | zyryanka
# Processing Record 39 of Set 10 | olafsvik
# Processing Record 40 of Set 10 | karachi
# Processing Record 41 of Set 10 | emerald
# Processing Record 42 of Set 10 | aklavik
# Processing Record 43 of Set 10 | mirandopolis
# Processing Record 44 of Set 10 | alice springs
# Processing Record 45 of Set 10 | shelburne
# Processing Record 46 of Set 10 | tasbuget
# City not found. Skipping...
# Processing Record 47 of Set 10 | yalvac
# Processing Record 48 of Set 10 | erzin
# Processing Record 49 of Set 10 | hovd
# Processing Record 50 of Set 10 | flagstaff
# Processing Record 1 of Set 11 | kargasok
# Processing Record 2 of Set 11 | escanaba
# Processing Record 3 of Set 11 | song phi nong
# Processing Record 4 of Set 11 | awjilah
# Processing Record 5 of Set 11 | awbari
# Processing Record 6 of Set 11 | seoul
# Processing Record 7 of Set 11 | jiayuguan
# Processing Record 8 of Set 11 | uray
# Processing Record 9 of Set 11 | berlevag
# Processing Record 10 of Set 11 | jijiga
# Processing Record 11 of Set 11 | san cristobal
# Processing Record 12 of Set 11 | hambantota
# Processing Record 13 of Set 11 | umm kaddadah
# Processing Record 14 of Set 11 | vardo
# Processing Record 15 of Set 11 | tomatlan
# Processing Record 16 of Set 11 | dinguiraye
# Processing Record 17 of Set 11 | aksha
# Processing Record 18 of Set 11 | sharkan
# Processing Record 19 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 20 of Set 11 | shizunai
# Processing Record 21 of Set 11 | shahr-e babak
# Processing Record 22 of Set 11 | taksimo
# Processing Record 23 of Set 11 | ovalle
# Processing Record 24 of Set 11 | banff
# Processing Record 25 of Set 11 | norden
# Processing Record 26 of Set 11 | alofi
# Processing Record 27 of Set 11 | tahoua
# Processing Record 28 of Set 11 | sao joao da barra
# Processing Record 29 of Set 11 | belomorsk
# Processing Record 30 of Set 11 | lakatoro
# Processing Record 31 of Set 11 | lipari
# Processing Record 32 of Set 11 | moen
# Processing Record 33 of Set 11 | cayenne
# Processing Record 34 of Set 11 | mumbwa
# Processing Record 35 of Set 11 | tessalit
# Processing Record 36 of Set 11 | mandra
# Processing Record 37 of Set 11 | namibe
# Processing Record 38 of Set 11 | duku
# Processing Record 39 of Set 11 | te anau
# Processing Record 40 of Set 11 | celje
# Processing Record 41 of Set 11 | imbituba
# Processing Record 42 of Set 11 | shatrovo
# Processing Record 43 of Set 11 | malwan
# City not found. Skipping...
# Processing Record 44 of Set 11 | makokou
# Processing Record 45 of Set 11 | villa rica
# Processing Record 46 of Set 11 | naze
# Processing Record 47 of Set 11 | tsihombe
# City not found. Skipping...
# Processing Record 48 of Set 11 | hofn
# Processing Record 49 of Set 11 | praia
# Processing Record 50 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 1 of Set 12 | prince rupert
# Processing Record 2 of Set 12 | kieta
# Processing Record 3 of Set 12 | baillif
# Processing Record 4 of Set 12 | mosquera
# Processing Record 5 of Set 12 | eyl
# Processing Record 6 of Set 12 | ialibu
# Processing Record 7 of Set 12 | aleksandrov gay
# Processing Record 8 of Set 12 | benjamin constant
# Processing Record 9 of Set 12 | brikama
# Processing Record 10 of Set 12 | aitape
# Processing Record 11 of Set 12 | verkhnechusovskiye gorodki
# Processing Record 12 of Set 12 | rocha
# Processing Record 13 of Set 12 | alta floresta
# Processing Record 14 of Set 12 | la roche-sur-yon
# Processing Record 15 of Set 12 | hohhot
# Processing Record 16 of Set 12 | jiddah
# City not found. Skipping...
# Processing Record 17 of Set 12 | takapau
# Processing Record 18 of Set 12 | porto santo
# Processing Record 19 of Set 12 | makurdi
# Processing Record 20 of Set 12 | manaus
# Processing Record 21 of Set 12 | lufilufi
# Processing Record 22 of Set 12 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 23 of Set 12 | vaitupu
# City not found. Skipping...
# Processing Record 24 of Set 12 | christchurch
# Processing Record 25 of Set 12 | la asuncion
# Processing Record 26 of Set 12 | streator
# Processing Record 27 of Set 12 | paranhos
# Processing Record 28 of Set 12 | ushtobe
# Processing Record 29 of Set 12 | marmande
# Processing Record 30 of Set 12 | boshnyakovo
# Processing Record 31 of Set 12 | havre
# Processing Record 32 of Set 12 | raudeberg
# Processing Record 33 of Set 12 | beira
# Processing Record 34 of Set 12 | marawi
# Processing Record 35 of Set 12 | bartica
# Processing Record 36 of Set 12 | mbandaka
# Processing Record 37 of Set 12 | namatanai
# Processing Record 38 of Set 12 | swellendam
# Processing Record 39 of Set 12 | carballo
# Processing Record 40 of Set 12 | san matias
# Processing Record 41 of Set 12 | goderich
# Processing Record 42 of Set 12 | koltubanovskiy
# Processing Record 43 of Set 12 | coquimbo
# Processing Record 44 of Set 12 | bondo
# Processing Record 45 of Set 12 | gat
# Processing Record 46 of Set 12 | pangody
# Processing Record 47 of Set 12 | broome
# Processing Record 48 of Set 12 | cacapava do sul
# Processing Record 49 of Set 12 | lebedinyy
# Processing Record 50 of Set 12 | mogadishu
# Processing Record 1 of Set 13 | buri
# Processing Record 2 of Set 13 | paita
# Processing Record 3 of Set 13 | iskateley
# Processing Record 4 of Set 13 | kaitong
# Processing Record 5 of Set 13 | kati
# Processing Record 6 of Set 13 | sendafa
# Processing Record 7 of Set 13 | trapani
# Processing Record 8 of Set 13 | kharan
# Processing Record 9 of Set 13 | kachiry
# Processing Record 10 of Set 13 | quesada
# Processing Record 11 of Set 13 | yining
# Processing Record 12 of Set 13 | safaga
# Processing Record 13 of Set 13 | sinnamary
# Processing Record 14 of Set 13 | lexington
# Processing Record 15 of Set 13 | yulara
# Processing Record 16 of Set 13 | dicabisagan
# Processing Record 17 of Set 13 | weihe
# Processing Record 18 of Set 13 | savyntsi
# Processing Record 19 of Set 13 | cosala
# Processing Record 20 of Set 13 | anqing
# Processing Record 21 of Set 13 | vitim
# Processing Record 22 of Set 13 | timra
# Processing Record 23 of Set 13 | akonolinga
# Processing Record 24 of Set 13 | mackay
# Processing Record 25 of Set 13 | puerto escondido
# Processing Record 26 of Set 13 | mega
# Processing Record 27 of Set 13 | spisske podhradie
# Processing Record 28 of Set 13 | abancay
# Processing Record 29 of Set 13 | ust-barguzin
# Processing Record 30 of Set 13 | sorland
# Processing Record 31 of Set 13 | harbin
# Processing Record 32 of Set 13 | boyolangu
# Processing Record 33 of Set 13 | otradnoye
# Processing Record 34 of Set 13 | roald
# Processing Record 35 of Set 13 | retalhuleu
# Processing Record 36 of Set 13 | nemuro
# Processing Record 37 of Set 13 | concarneau
# Processing Record 38 of Set 13 | olbia
# Processing Record 39 of Set 13 | masinigudi
# Processing Record 40 of Set 13 | zimapan
# Processing Record 41 of Set 13 | stromness
# Processing Record 42 of Set 13 | goure
# Processing Record 43 of Set 13 | a
# City not found. Skipping...
# Processing Record 44 of Set 13 | pop
# Processing Record 45 of Set 13 | sisimiut
# Processing Record 46 of Set 13 | wewak
# Processing Record 47 of Set 13 | deer lake
# Processing Record 48 of Set 13 | san juan
# Processing Record 49 of Set 13 | tiznit
# Processing Record 50 of Set 13 | barinas
# Processing Record 1 of Set 14 | mulki
# Processing Record 2 of Set 14 | nizhniy kuranakh
# Processing Record 3 of Set 14 | lerwick
# Processing Record 4 of Set 14 | adrar
# Processing Record 5 of Set 14 | westport
# Processing Record 6 of Set 14 | filadelfia
# Processing Record 7 of Set 14 | nishihara
# Processing Record 8 of Set 14 | paamiut
# Processing Record 9 of Set 14 | dongsheng
# Processing Record 10 of Set 14 | hailar
# Processing Record 11 of Set 14 | pouembout
# Processing Record 12 of Set 14 | lasa
# Processing Record 13 of Set 14 | mikhaylovka
# Processing Record 14 of Set 14 | tshikapa
# Processing Record 15 of Set 14 | bayan
# Processing Record 16 of Set 14 | hervey bay
# Processing Record 17 of Set 14 | mgandu
# Processing Record 18 of Set 14 | kalaleh
# Processing Record 19 of Set 14 | chihuahua
# Processing Record 20 of Set 14 | little rock
# Processing Record 21 of Set 14 | kirando
# Processing Record 22 of Set 14 | caravelas
# Processing Record 23 of Set 14 | ust-omchug
# Processing Record 24 of Set 14 | esperance
# Processing Record 25 of Set 14 | karamken
# City not found. Skipping...
# Processing Record 26 of Set 14 | tiquisate
# Processing Record 27 of Set 14 | douala
# Processing Record 28 of Set 14 | puro
# Processing Record 29 of Set 14 | salinopolis
# Processing Record 30 of Set 14 | toppenish
# Processing Record 31 of Set 14 | cairns
# Processing Record 32 of Set 14 | vzmorye
# Processing Record 33 of Set 14 | srednekolymsk
# Processing Record 34 of Set 14 | tungkang
# City not found. Skipping...
# Processing Record 35 of Set 14 | keuruu
# Processing Record 36 of Set 14 | poltavka
# Processing Record 37 of Set 14 | opuwo
# Processing Record 38 of Set 14 | temaraia
# City not found. Skipping...
# Processing Record 39 of Set 14 | biak
# Processing Record 40 of Set 14 | wanxian
# Processing Record 41 of Set 14 | chany
# Processing Record 42 of Set 14 | talaya
# Processing Record 43 of Set 14 | mehamn
# Processing Record 44 of Set 14 | sept-iles
# Processing Record 45 of Set 14 | mogadouro
# Processing Record 46 of Set 14 | moskovskiy
# Processing Record 47 of Set 14 | auki
# Processing Record 48 of Set 14 | luanda
# Processing Record 49 of Set 14 | virden
# Processing Record 50 of Set 14 | mangrol
# Processing Record 1 of Set 15 | salinas
# Processing Record 2 of Set 15 | aflu
# City not found. Skipping...
# Processing Record 3 of Set 15 | nguruka
# Processing Record 4 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 5 of Set 15 | khasan
# Processing Record 6 of Set 15 | benghazi
# Processing Record 7 of Set 15 | sayansk
# Processing Record 8 of Set 15 | halalo
# City not found. Skipping...
# Processing Record 9 of Set 15 | banyo
# Processing Record 10 of Set 15 | mashhad
# Processing Record 11 of Set 15 | tarabha
# Processing Record 12 of Set 15 | qinhuangdao
# Processing Record 13 of Set 15 | tunceli
# Processing Record 14 of Set 15 | shubarshi
# Processing Record 15 of Set 15 | roma
# Processing Record 16 of Set 15 | boende
# Processing Record 17 of Set 15 | puerto cabezas
# Processing Record 18 of Set 15 | pithiviers
# Processing Record 19 of Set 15 | buin
# Processing Record 20 of Set 15 | otane
# Processing Record 21 of Set 15 | san rafael
# Processing Record 22 of Set 15 | marystown
# Processing Record 23 of Set 15 | howard springs
# Processing Record 24 of Set 15 | vila velha
# Processing Record 25 of Set 15 | lodja
# Processing Record 26 of Set 15 | hirara
# Processing Record 27 of Set 15 | taltal
# Processing Record 28 of Set 15 | benjamin hill
# Processing Record 29 of Set 15 | pa sang
# Processing Record 30 of Set 15 | khammam
# Processing Record 31 of Set 15 | lumphat
# Processing Record 32 of Set 15 | bonthe
# Processing Record 33 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 34 of Set 15 | san francisco
# Processing Record 35 of Set 15 | teodoro sampaio
# Processing Record 36 of Set 15 | dwarka
# Processing Record 37 of Set 15 | kondapalle
# Processing Record 38 of Set 15 | zemlyansk
# Processing Record 39 of Set 15 | ardakan
# Processing Record 40 of Set 15 | cubuk
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Saint-Philippe      RE -21.3585   55.7679     75.22        80          34
# 1        Jamestown      US  42.0970  -79.2353     67.32        68          75
# 2        Busselton      AU -33.6500  115.3333     42.04        67          59
# 3             Mayo      US  38.8876  -76.5119     78.62        69           1
# 4   Ribeira Grande      PT  38.5167  -28.7000     70.20        73          75
# 5        Fairbanks      US  64.8378 -147.7164     26.60        92          75
# 6          Rikitea      PF -23.1203 -134.9692     74.62        73         100
# 7           Kijang      KR  35.2442  129.2139     51.53        57           0
# 8             Hilo      US  19.7297 -155.0900     71.80        88          90
# 9  Bambous Virieux      MU -20.3428   57.7575     75.45        73          40
#
#    Wind Speed Current Description
# 0       13.29    scattered clouds
# 1        7.00       broken clouds
# 2        6.15       broken clouds
# 3        5.01           clear sky
# 4       10.36       broken clouds
# 5        0.00       broken clouds
# 6       19.15     overcast clouds
# 7        5.53           clear sky
# 8        5.75          light rain
# 9       14.97          light rain

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
